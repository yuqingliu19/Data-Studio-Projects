# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('Births by Age (Sample Survey).xls', skiprows=2)
df.head()
# Out:
#                                           Indicators    2015   2014   2013  \
# 0                     Births (Sample Survey)(person)  175309  11377  11022
# 1  Births, Childbearing Women Aged 15-19 (Sample ...    5305    354    261
# 2  Births, Childbearing Women Aged 15 (Sample Sur...     106      5      2
# 3  Births, Childbearing Women Aged 16 (Sample Sur...     340     16     14
# 4  Births, Childbearing Women Aged 17 (Sample Sur...     747     55     44
#
#       2012  2011  2010   2009   2008     2007   2006
# 0  11379.0  9684   NaN  11468  12405  12169.0  11509
# 1    241.0   236   NaN    242    228    178.0    227
# 2      NaN     7   NaN      1      1      NaN      0
# 3     11.0     9   NaN     10      2      NaN      7
# 4     38.0    35   NaN     20     15     12.0     25

# %%
df1 = df.transpose().reset_index()
df1
# Out:
#          index                               0  \
# 0   Indicators  Births (Sample Survey)(person)
# 1         2015                          175309
# 2         2014                           11377
# 3         2013                           11022
# 4         2012                           11379
# 5         2011                            9684
# 6         2010                             NaN
# 7         2009                           11468
# 8         2008                           12405
# 9         2007                           12169
# 10        2006                           11509
#
#                                                     1  \
# 0   Births, Childbearing Women Aged 15-19 (Sample ...
# 1                                                5305
# 2                                                 354
# 3                                                 261
# 4                                                 241
# 5                                                 236
# ...

# %%
df1.drop(df1.columns[[3, 4, 5, 6, 7, 9, 10, 11, 12, 13, 15, 16, 17, 18, 19, 21, 22, 23, 24, 25, 27, 28, 29, 30, 31, 33, 34, 35, 36, 37, 39, 40, 41, 42, 43]], axis=1, inplace=True)
df1
# Out:
#          index                               0  \
# 0   Indicators  Births (Sample Survey)(person)
# 1         2015                          175309
# 2         2014                           11377
# 3         2013                           11022
# 4         2012                           11379
# 5         2011                            9684
# 6         2010                             NaN
# 7         2009                           11468
# 8         2008                           12405
# 9         2007                           12169
# 10        2006                           11509
#
#                                                     1  \
# 0   Births, Childbearing Women Aged 15-19 (Sample ...
# 1                                                5305
# 2                                                 354
# 3                                                 261
# 4                                                 241
# 5                                                 236
# ...

# %%
df2 = df1.drop(df1.index[[0]])
df2
# Out:
#    index       0     1      7     13     19     25    31    37
# 1   2015  175309  5305  42170  71154  34969  13906  4908  2896
# 2   2014   11377   354   3606   4481   1994    690   200    52
# 3   2013   11022   261   3320   4256   2074    785   242    84
# 4   2012   11379   241   3735   4227   2045    770   284    77
# 5   2011    9684   236   3547   3420   1644    594   179    62
# 6   2010     NaN   NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 7   2009   11468   242   3779   3651   2007   1060   428   270
# 8   2008   12405   228   3867   3948   2229   1212   566   284
# 9   2007   12169   178   3755   4100   2310   1189   390   198
# 10  2006   11509   227   3948   3813   2236    940   259    86

# %%
df2.rename(columns={'index': 'Year', 0: 'Births', 1:'Births, Childbearing Women Aged 15-19', 7:'Births, Childbearing Women Aged 20-24', 13:'Births, Childbearing Women Aged 25-29', 19:'Births, Childbearing Women Aged 30-34',25:'Births, Childbearing Women Aged 35-39', 31:'Births, Childbearing Women Aged 40-44', 37:'Births, Childbearing Women Aged 45-49' }, inplace=True)
df2
# Out:
#     Year  Births Births, Childbearing Women Aged 15-19  \
# 1   2015  175309                                  5305
# 2   2014   11377                                   354
# 3   2013   11022                                   261
# 4   2012   11379                                   241
# 5   2011    9684                                   236
# 6   2010     NaN                                   NaN
# 7   2009   11468                                   242
# 8   2008   12405                                   228
# 9   2007   12169                                   178
# 10  2006   11509                                   227
#
#    Births, Childbearing Women Aged 20-24  \
# 1                                  42170
# 2                                   3606
# 3                                   3320
# 4                                   3735
# 5                                   3547
# 6                                    NaN
# 7                                   3779
# ...

# %%
df_2nd = pd.read_excel('Births by Age, 2nd Birth (Sample Survey).xls', skiprows=2)
df_2nd.head()
# Out:
#                                           Indicators     2015    2014    2013  \
# 0          Births, 2st Birth (Sample Survey)(person)  69695.0  4082.0  3431.0
# 1  Births, 2st Birth, Childbearing Women Aged 15-...    644.0    28.0    17.0
# 2  Births, 2st Birth, Childbearing Women Aged 15 ...      9.0     NaN     NaN
# 3  Births, 2st Birth, Childbearing Women Aged 16 ...     27.0     NaN     1.0
# 4  Births, 2st Birth, Childbearing Women Aged 17 ...     64.0     3.0     1.0
#
#      2012    2011  2010    2009    2008    2007    2006
# 0  3462.0  2837.0   NaN  3363.0  3573.0  3590.0  3492.0
# 1     9.0    17.0   NaN    22.0    11.0    12.0    16.0
# 2     NaN     NaN   NaN     NaN     NaN     NaN     0.0
# 3     NaN     NaN   NaN     2.0     NaN     NaN     0.0
# 4     1.0     2.0   NaN     2.0     1.0     2.0     1.0

# %%
df_Fer = pd.read_excel('Fertility Rate by Age (Sample Survey).xls', skiprows=2)
df_Fer.head()
# Out:
#                                           Indicators   2015   2014   2013  \
# 0                  Fertility Rate (Sample Survey)(?)  30.93  37.33  35.68
# 1  Fertility Rate, Childbearing Women Aged 15-19 ...   9.19  11.19   7.84
# 2  Fertility Rate, Childbearing Women Aged 15 (Sa...   1.09   0.87   0.38
# 3  Fertility Rate, Childbearing Women Aged 16 (Sa...   3.14   2.63   2.03
# 4  Fertility Rate, Childbearing Women Aged 17 (Sa...   6.69   9.08   6.19
#
#     2012   2011  2010   2009   2008   2007   2006
# 0  35.89  29.75   NaN  36.14  38.83  37.46  34.99
# 1   6.72   6.16   NaN   6.16   5.26   3.83   4.59
# 2    NaN   0.94   NaN   0.12   0.10    NaN   0.04
# 3   1.45   1.24   NaN   1.36   0.25   0.03   0.59
# 4   5.46   4.82   NaN   2.64   1.84   1.11   2.41

# %%
df_F2nd = pd.read_excel('Fertility Rate by Age, 2rd Birth (Sample Survey).xls', skiprows=2)
df_F2nd.head()
# Out:
#                                           Indicators   2015   2014   2013  \
# 0       Fertility Rate, 2rd Birth (Sample Survey)(?)  12.30  13.40  11.11
# 1  Fertility Rate, 2rd Birth, Childbearing Women ...   1.12   0.89   0.50
# 2  Fertility Rate, 2rd Birth, Childbearing Women ...   0.09    NaN   0.03
# 3  Fertility Rate, 2rd Birth, Childbearing Women ...   0.25    NaN   0.08
# 4  Fertility Rate, 2rd Birth, Childbearing Women ...   0.57   0.50   0.12
#
#     2012  2011  2010   2009   2008   2007   2006
# 0  10.92  8.72   NaN  10.60  11.18  11.05  10.62
# 1   0.25  0.44   NaN   0.57   0.27   0.25   0.31
# 2    NaN   NaN   NaN    NaN    NaN    NaN   0.00
# 3    NaN   NaN   NaN   0.22    NaN    NaN   0.00
# 4   0.15  0.25   NaN   0.25   0.12   0.17   0.08

# %%
df_F2 = df_F2nd.transpose().reset_index()
df_F2
# Out:
#          index                                             0  \
# 0   Indicators  Fertility Rate, 2rd Birth (Sample Survey)(?)
# 1         2015                                          12.3
# 2         2014                                          13.4
# 3         2013                                         11.11
# 4         2012                                         10.92
# 5         2011                                          8.72
# 6         2010                                           NaN
# 7         2009                                          10.6
# 8         2008                                         11.18
# 9         2007                                         11.05
# 10        2006                                         10.62
#
#                                                     1  \
# 0   Fertility Rate, 2rd Birth, Childbearing Women ...
# 1                                                1.12
# 2                                                0.89
# ...

# %%
df_F2.drop(df_F2.columns[[3, 4, 5, 6, 7, 9, 10, 11, 12, 13, 15, 16, 17, 18, 19, 21, 22, 23, 24, 25, 27, 28, 29, 30, 31, 33, 34, 35, 36, 37, 39, 40, 41, 42, 43]], axis=1, inplace=True)
df_F2
# Out:
#          index                                             0  \
# 0   Indicators  Fertility Rate, 2rd Birth (Sample Survey)(?)
# 1         2015                                          12.3
# 2         2014                                          13.4
# 3         2013                                         11.11
# 4         2012                                         10.92
# 5         2011                                          8.72
# 6         2010                                           NaN
# 7         2009                                          10.6
# 8         2008                                         11.18
# 9         2007                                         11.05
# 10        2006                                         10.62
#
#                                                     1  \
# 0   Fertility Rate, 2rd Birth, Childbearing Women ...
# 1                                                1.12
# 2                                                0.89
# ...

# %%
df_F2.drop(df_F2.columns[[9, 10]], axis=1, inplace=True)
df_F2
# Out:
#          index                                             0  \
# 0   Indicators  Fertility Rate, 2rd Birth (Sample Survey)(?)
# 1         2015                                          12.3
# 2         2014                                          13.4
# 3         2013                                         11.11
# 4         2012                                         10.92
# 5         2011                                          8.72
# 6         2010                                           NaN
# 7         2009                                          10.6
# 8         2008                                         11.18
# 9         2007                                         11.05
# 10        2006                                         10.62
#
#                                                     1  \
# 0   Fertility Rate, 2rd Birth, Childbearing Women ...
# 1                                                1.12
# 2                                                0.89
# ...

# %%
df_F2N = df_F2.drop(df_F2.index[[0]])
df_F2N
# Out:
#    index      0     1      7     13     19     25    31    37
# 1   2015   12.3  1.12  13.39   28.8  25.42  10.96  2.45  1.23
# 2   2014   13.4  0.89  17.96  34.77  25.74   9.71  2.22  0.54
# 3   2013  11.11   0.5  10.73  29.75  24.15   9.95  2.35  0.61
# 4   2012  10.92  0.25  11.78  28.44  24.46   9.91  2.88  0.58
# 5   2011   8.72  0.44   8.58   22.8  21.77   7.66  1.69  0.52
# 6   2010    NaN   NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 7   2009   10.6  0.57   8.29  29.33  27.62  10.92  2.16  1.22
# 8   2008  11.18  0.27   9.35  28.25  28.03  11.31  3.33  1.96
# 9   2007  11.05  0.25   7.68   27.9  28.53  11.71  2.72  1.58
# 10  2006  10.62  0.31   8.02  27.77  29.23   9.95  1.83  0.72

# %%
df_F2N.rename(columns={'index': 'Year', 0: 'Fertility Rate, 2nd Birth ', 1:'2nd Birth, Women Aged 15-19', 7:'2nd Birth, Women Aged 20-24', 13:'2nd Birth, Women Aged 25-29', 19:'2nd Birth, Women Aged 30-34',25:'2nd Birth, Women Aged 35-39', 31:'2nd Birth, Women Aged 40-44', 37:'2nd Birth, Women Aged 45-49' }, inplace=True)
df_F2N
# Out:
#     Year Fertility Rate, 2nd Birth  2nd Birth, Women Aged 15-19  \
# 1   2015                       12.3                        1.12
# 2   2014                       13.4                        0.89
# 3   2013                      11.11                         0.5
# 4   2012                      10.92                        0.25
# 5   2011                       8.72                        0.44
# 6   2010                        NaN                         NaN
# 7   2009                       10.6                        0.57
# 8   2008                      11.18                        0.27
# 9   2007                      11.05                        0.25
# 10  2006                      10.62                        0.31
#
#    2nd Birth, Women Aged 20-24 2nd Birth, Women Aged 25-29  \
# 1                        13.39                        28.8
# 2                        17.96                       34.77
# 3                        10.73                       29.75
# ...

# %%
df_NewF2 = df_F2N.drop(df_F2N.index[[5]])
df_NewF2
# Out:
#     Year Fertility Rate, 2nd Birth  2nd Birth, Women Aged 15-19  \
# 1   2015                       12.3                        1.12
# 2   2014                       13.4                        0.89
# 3   2013                      11.11                         0.5
# 4   2012                      10.92                        0.25
# 5   2011                       8.72                        0.44
# 7   2009                       10.6                        0.57
# 8   2008                      11.18                        0.27
# 9   2007                      11.05                        0.25
# 10  2006                      10.62                        0.31
#
#    2nd Birth, Women Aged 20-24 2nd Birth, Women Aged 25-29  \
# 1                        13.39                        28.8
# 2                        17.96                       34.77
# 3                        10.73                       29.75
# 4                        11.78                       28.44
# ...

# %%
df_NewF2.sort_values(by='Year', ascending = True, inplace=True)

# %%
df_NewF2
# Out:
#     Year Fertility Rate, 2nd Birth  2nd Birth, Women Aged 15-19  \
# 10  2006                      10.62                        0.31
# 9   2007                      11.05                        0.25
# 8   2008                      11.18                        0.27
# 7   2009                       10.6                        0.57
# 5   2011                       8.72                        0.44
# 4   2012                      10.92                        0.25
# 3   2013                      11.11                         0.5
# 2   2014                       13.4                        0.89
# 1   2015                       12.3                        1.12
#
#    2nd Birth, Women Aged 20-24 2nd Birth, Women Aged 25-29  \
# 10                        8.02                       27.77
# 9                         7.68                        27.9
# 8                         9.35                       28.25
# 7                         8.29                       29.33
# ...

# %%
df_NewF2.plot(x='Year')
