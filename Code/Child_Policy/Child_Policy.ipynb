# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df_com = pd.read_excel('compare.xlsx')
df_com
# Out:
#      Year  Fertility Rate Country
# 0    1960         5.75400   China
# 1    1961         5.90400   China
# 2    1962         6.06100   China
# 3    1963         6.20600   China
# 4    1964         6.32000   China
# 5    1965         6.38500   China
# 6    1966         6.38400   China
# 7    1967         6.31700   China
# 8    1968         6.18400   China
# 9    1969         5.98600   China
# 10   1970         5.72500   China
# 11   1971         5.40300   China
# 12   1972         5.03600   China
# 13   1973         4.64400   China
# 14   1974         4.24500   China
# 15   1975         3.86100   China
# 16   1976         3.51000   China
# 17   1977         3.20200   China
# 18   1978         2.94500   China
# 19   1979         2.74700   China
# 20   1980         2.61300   China
# 21   1981         2.54600   China
# 22   1982         2.53300   China
# 23   1983         2.55600   China
# 24   1984         2.60200   China
# 25   1985         2.65000   China
# ...

# %%
sns.lmplot(x="Year", y="Fertility Rate", hue="Country", data=df_com)

# %%
df_com.plot(x='Year', y='Fertility Rate')

# %%
#df_growth = pd.read_excel('POPULATION_GROWTH_RATE.xlsx', skiprows=16)

# %%
#df_growth[df_growth['Region, subregion, country or area *']=='China']

# %%
#df_both = pd.read_excel('TOTAL_POPULATION_BOTH_SEXES.xlsx', skiprows=16)

# %%
#df_fertility = pd.read_excel('AGE_SPECIFIC_FERTILITY.xlsx', skiprows=16)

# %%
#df_fertility[df_fertility['Region, subregion, country or area *']=='China']

# %%
df_fert = pd.read_excel('API_SP.DYN.TFRT.IN_DS2_en_excel_v2.xls', skiprows=3)
df_fert
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
df_new = df_fert[df_fert['Country Name']=='China'].transpose().reset_index()

# %%
df_CHN = df_new.drop(df_new.index[[0,1,2,3]])

# %%
df_CHN.rename(columns={'index': 'Year', 38: 'Fertility Rate'}, inplace=True)
df_CHN
# Out:
#     Year Fertility Rate
# 4   1960          5.754
# 5   1961          5.904
# 6   1962          6.061
# 7   1963          6.206
# 8   1964           6.32
# 9   1965          6.385
# 10  1966          6.384
# 11  1967          6.317
# 12  1968          6.184
# 13  1969          5.986
# 14  1970          5.725
# 15  1971          5.403
# 16  1972          5.036
# 17  1973          4.644
# 18  1974          4.245
# 19  1975          3.861
# 20  1976           3.51
# 21  1977          3.202
# 22  1978          2.945
# 23  1979          2.747
# 24  1980          2.613
# 25  1981          2.546
# 26  1982          2.533
# 27  1983          2.556
# 28  1984          2.602
# 29  1985           2.65
# 30  1986          2.678
# 31  1987          2.676
# 32  1988          2.634
# 33  1989          2.551
# 34  1990          2.428
# 35  1991          2.276
# 36  1992          2.111
# 37  1993          1.952
# 38  1994          1.806
# 39  1995          1.684
# 40  1996           1.59
# ...

# %%
df_CHN.plot(x='Year', y='Fertility Rate')

# %%
Workbook12

# %%
df_both = pd.read_excel('Workbook12.xlsx')
df_both
# Out:
#      Year  Fertility Rate country
# 0    1960         5.75400   China
# 1    1961         5.90400   China
# 2    1962         6.06100   China
# 3    1963         6.20600   China
# 4    1964         6.32000   China
# 5    1965         6.38500   China
# 6    1966         6.38400   China
# 7    1967         6.31700   China
# 8    1968         6.18400   China
# 9    1969         5.98600   China
# 10   1970         5.72500   China
# 11   1971         5.40300   China
# 12   1972         5.03600   China
# 13   1973         4.64400   China
# 14   1974         4.24500   China
# 15   1975         3.86100   China
# 16   1976         3.51000   China
# 17   1977         3.20200   China
# 18   1978         2.94500   China
# 19   1979         2.74700   China
# 20   1980         2.61300   China
# 21   1981         2.54600   China
# 22   1982         2.53300   China
# 23   1983         2.55600   China
# 24   1984         2.60200   China
# 25   1985         2.65000   China
# ...

# %%
fig, ax = plt.subplots()
colors = {
    'China':'#ff6060',
    'World':'#ababab'
}
for country, group_df in df_both.groupby('country'):
    line_color = colors[country]
    group_df.plot(x='Year', y='Fertility Rate', ax=ax, label=country, color=line_color)
plt.savefig('fertility rate.pdf')

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
df_both.groupby('country').plot(x='Year', y='Fertility Rate', ax=ax)
# Out:
# country
# China    Axes(0.125,0.125;0.775x0.755)
# World    Axes(0.125,0.125;0.775x0.755)
# dtype: object

# %%
df2 = df_fert[df_fert['Country Name']=='World'].transpose().reset_index()

# %%
df_World = df2.drop(df2.index[[0,1,2,3]])

# %%
df_World.rename(columns={'index': 'Year', 257: 'Fertility Rate'}, inplace=True)
df_World
# Out:
#     Year Fertility Rate
# 4   1960        4.98426
# 5   1961        5.00791
# 6   1962        5.03003
# 7   1963         5.0505
# 8   1964        5.06106
# 9   1965        5.04466
# 10  1966        4.99518
# 11  1967        4.97848
# 12  1968        4.92763
# 13  1969        4.86076
# 14  1970        4.78295
# 15  1971        4.67585
# 16  1972        4.54788
# 17  1973        4.41951
# 18  1974        4.29748
# 19  1975        4.16552
# 20  1976        4.04724
# 21  1977        3.94409
# 22  1978        3.84917
# 23  1979        3.77941
# 24  1980        3.71903
# 25  1981        3.66119
# 26  1982        3.63136
# 27  1983        3.59871
# 28  1984        3.56882
# 29  1985          3.543
# 30  1986        3.50998
# 31  1987        3.46988
# 32  1988        3.41805
# 33  1989        3.35042
# 34  1990        3.27898
# 35  1991        3.19096
# 36  1992        3.10398
# 37  1993        3.01479
# 38  1994        2.94013
# 39  1995        2.86875
# 40  1996        2.81063
# ...

# %%
df_World.plot(x='Year', y='Fertility Rate')

# %%
df3 = df_fert[df_fert['Country Name']=='United States'].transpose().reset_index()

# %%
df_US = df3.drop(df3.index[[0,1,2,3]])

# %%
df_US.rename(columns={'index': 'Year', 249: 'Fertility Rate'}, inplace=True)
df_US
# Out:
#     Year Fertility Rate
# 4   1960          3.654
# 5   1961           3.62
# 6   1962          3.461
# 7   1963          3.319
# 8   1964           3.19
# 9   1965          2.913
# 10  1966          2.721
# 11  1967          2.558
# 12  1968          2.464
# 13  1969          2.456
# 14  1970           2.48
# 15  1971          2.266
# 16  1972           2.01
# 17  1973          1.879
# 18  1974          1.835
# 19  1975          1.774
# 20  1976          1.738
# 21  1977           1.79
# 22  1978           1.76
# 23  1979          1.808
# 24  1980         1.8395
# 25  1981          1.812
# 26  1982         1.8275
# 27  1983          1.799
# 28  1984         1.8065
# 29  1985          1.844
# 30  1986         1.8375
# 31  1987          1.872
# 32  1988          1.934
# 33  1989          2.014
# 34  1990          2.081
# 35  1991         2.0625
# 36  1992          2.046
# 37  1993         2.0195
# 38  1994         2.0015
# 39  1995          1.978
# 40  1996          1.976
# ...

# %%
df_US.plot(x='Year', y='Fertility Rate')

# %%
df_male = pd.read_excel('POPULATION_BY_AGE_MALE.xlsx', skiprows=16)

# %%
df_CM = df_male[df_male['Region, subregion, country or area *']=='China']

# %%
df_CM.drop(df_CM.columns[[0, 1, 2, 3, 4]], axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_CM.rename(columns={'Reference date (as of 1 July)': 'Year'}, inplace=True)
df_CM
# Out:
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py:2746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)
#       Year        0-4        5-9      10-14      15-19      20-24      25-29  \
# 1078  1950  39673.730  30581.430  29491.632  27805.596  24688.584  21732.884
# 1079  1955  52885.257  36660.588  29422.744  28623.844  26932.622  23884.269
# 1080  1960  49388.451  49204.560  35521.915  28667.598  27803.158  26100.232
# 1081  1965  59224.413  45882.723  47677.308  34564.394  27796.926  26933.907
# 1082  1970  68818.257  56617.193  45343.933  47193.460  34097.208  27340.026
# 1083  1975  64780.775  67055.261  56097.800  45018.897  46774.328  33714.868
# 1084  1980  51865.112  63673.573  66595.354  55842.995  44788.547  46476.937
# ...

# %%
df_1950M = df_CM[df_CM['Year'] == 1950].transpose().reset_index()
df_1950M
# Out:
#     index     1078
# 0    Year     1950
# 1     0-4  39673.7
# 2     5-9  30581.4
# 3   10-14  29491.6
# 4   15-19  27805.6
# 5   20-24  24688.6
# 6   25-29  21732.9
# 7   30-34  21548.4
# 8   35-39  19318.9
# 9   40-44  16548.3
# 10  45-49  14961.6
# 11  50-54  12255.5
# 12  55-59  10717.6
# 13  60-64  8000.45
# 14  65-69  5634.93
# 15  70-74  2926.84
# 16  75-79  1402.09
# 17    80+  451.429
# 18  80-84        …
# 19  85-89        …
# 20  90-94        …
# 21  95-99        …
# 22   100+        …

# %%
df_1950M.rename(columns={'index': 'Age', 1078: '1950'}, inplace=True)
df_1950M
# Out:
#       Age     1950
# 0    Year     1950
# 1     0-4  39673.7
# 2     5-9  30581.4
# 3   10-14  29491.6
# 4   15-19  27805.6
# 5   20-24  24688.6
# 6   25-29  21732.9
# 7   30-34  21548.4
# 8   35-39  19318.9
# 9   40-44  16548.3
# 10  45-49  14961.6
# 11  50-54  12255.5
# 12  55-59  10717.6
# 13  60-64  8000.45
# 14  65-69  5634.93
# 15  70-74  2926.84
# 16  75-79  1402.09
# 17    80+  451.429
# 18  80-84        …
# 19  85-89        …
# 20  90-94        …
# 21  95-99        …
# 22   100+        …

# %%
df_1950M.drop(df_1950M.index[0], inplace=True)
df_1950M
# Out:
#       Age     1950
# 1     0-4  39673.7
# 2     5-9  30581.4
# 3   10-14  29491.6
# 4   15-19  27805.6
# 5   20-24  24688.6
# 6   25-29  21732.9
# 7   30-34  21548.4
# 8   35-39  19318.9
# 9   40-44  16548.3
# 10  45-49  14961.6
# 11  50-54  12255.5
# 12  55-59  10717.6
# 13  60-64  8000.45
# 14  65-69  5634.93
# 15  70-74  2926.84
# 16  75-79  1402.09
# 17    80+  451.429
# 18  80-84        …
# 19  85-89        …
# 20  90-94        …
# 21  95-99        …
# 22   100+        …

# %%
df_female = pd.read_excel('POPULATION_BY_AGE_FEMALE.xlsx', skiprows=16)

# %%
df_CF = df_female[df_female['Region, subregion, country or area *']=='China']

# %%
df_CF.drop(df_CF.columns[[0, 1, 2, 3, 4]], axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_CF
# Out:
#       Reference date (as of 1 July)        0-4        5-9      10-14  \
# 1078                           1950  36834.184  26816.395  25332.924
# 1079                           1955  49710.882  34202.551  25985.902
# 1080                           1960  46502.389  46354.750  33264.901
# 1081                           1965  55485.891  43220.935  45049.883
# 1082                           1970  65769.841  53516.618  42799.476
# 1083                           1975  61024.404  64226.957  53076.159
# 1084                           1980  48755.963  60070.080  63848.263
# 1085                           1985  51342.533  48236.963  59799.273
# 1086                           1990  64221.230  50865.643  48060.674
# 1087                           1995  48842.274  63720.337  50716.774
# 1088                           2000  38289.360  48523.697  63568.624
# 1089                           2005  36769.009  38103.408  48409.516
# 1090                           2010  38106.254  36640.485  38015.584
# ...

# %%
df_CF.rename(columns={'Reference date (as of 1 July)': 'Year'}, inplace=True)
df_CF
# Out:
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py:2746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)
#       Year        0-4        5-9      10-14      15-19      20-24      25-29  \
# 1078  1950  36834.184  26816.395  25332.924  24438.981  21571.528  19977.100
# 1079  1955  49710.882  34202.551  25985.902  24745.883  23814.943  20877.872
# 1080  1960  46502.389  46354.750  33264.901  25453.245  24192.696  23133.019
# 1081  1965  55485.891  43220.935  45049.883  32526.081  24777.124  23437.996
# 1082  1970  65769.841  53516.618  42799.476  44662.820  32136.491  24407.783
# 1083  1975  61024.404  64226.957  53076.159  42540.170  44325.320  31821.244
# 1084  1980  48755.963  60070.080  63848.263  52867.149  42331.934  44048.354
# ...

# %%
df_1950 = df_CF[df_CF['Year'] == 1950].transpose().reset_index()
df_1950
# Out:
#     index     1078
# 0    Year     1950
# 1     0-4  36834.2
# 2     5-9  26816.4
# 3   10-14  25332.9
# 4   15-19    24439
# 5   20-24  21571.5
# 6   25-29  19977.1
# 7   30-34  19584.2
# 8   35-39  17816.8
# 9   40-44  15599.8
# 10  45-49  14081.7
# 11  50-54  11367.1
# 12  55-59  10566.7
# 13  60-64  8549.79
# 14  65-69  6805.96
# 15  70-74  4041.12
# 16  75-79  2234.07
# 17    80+  1061.05
# 18  80-84        …
# 19  85-89        …
# 20  90-94        …
# 21  95-99        …
# 22   100+        …

# %%
df_1950.rename(columns={'index': 'Age', 1078: '1950'}, inplace=True)
df_1950
# Out:
#       Age     1950
# 0    Year     1950
# 1     0-4  36834.2
# 2     5-9  26816.4
# 3   10-14  25332.9
# 4   15-19    24439
# 5   20-24  21571.5
# 6   25-29  19977.1
# 7   30-34  19584.2
# 8   35-39  17816.8
# 9   40-44  15599.8
# 10  45-49  14081.7
# 11  50-54  11367.1
# 12  55-59  10566.7
# 13  60-64  8549.79
# 14  65-69  6805.96
# 15  70-74  4041.12
# 16  75-79  2234.07
# 17    80+  1061.05
# 18  80-84        …
# 19  85-89        …
# 20  90-94        …
# 21  95-99        …
# 22   100+        …

# %%
df_1950.drop(df_1950.index[0], inplace=True)
df_1950
# Out:
#       Age     1950
# 1     0-4  36834.2
# 2     5-9  26816.4
# 3   10-14  25332.9
# 4   15-19    24439
# 5   20-24  21571.5
# 6   25-29  19977.1
# 7   30-34  19584.2
# 8   35-39  17816.8
# 9   40-44  15599.8
# 10  45-49  14081.7
# 11  50-54  11367.1
# 12  55-59  10566.7
# 13  60-64  8549.79
# 14  65-69  6805.96
# 15  70-74  4041.12
# 16  75-79  2234.07
# 17    80+  1061.05
# 18  80-84        …
# 19  85-89        …
# 20  90-94        …
# 21  95-99        …
# 22   100+        …

# %%
#df_F = df_female[df_female['Region, subregion, country or area *']=='China'].transpose().reset_index()

# %%
#df_Fe = df_F.drop(df_F.index[[0,1,2,3,4,5]])

# %%
#df_Fe.rename(columns={'index': 'Age', 1078: '1950', 1079:'1955', 1080:'1960', 1081:'1965', 1082:'1970', 1083:'1975', 1084:'1980', 1085:'1985', 1086:'1990', 1087:'1995', 1088:'2000', 1089:'2005', 1090:'2010', 1091:'2015'}, inplace=True)

# %%
#df_Fe

# %%
df_population = pd.read_excel('TOTAL_POPULATION_BOTH_SEXES.xlsx', skiprows=16)

# %%
df_population
# Out:
#      Index    Variant               Region, subregion, country or area *  \
# 0        1  Estimates                                              WORLD
# 1        2  Estimates                             More developed regions
# 2        3  Estimates                             Less developed regions
# 3        4  Estimates                          Least developed countries
# 4        5  Estimates  Less developed regions, excluding least develo...
# 5        6  Estimates            Less developed regions, excluding China
# 6        7  Estimates                              High-income countries
# 7        8  Estimates                            Middle-income countries
# 8        9  Estimates                      Upper-middle-income countries
# 9       10  Estimates                      Lower-middle-income countries
# 10      11  Estimates                               Low-income countries
# 11      12  Estimates                                 Sub-Saharan Africa
# ...

# %%
df_PC = df_population[df_population['Region, subregion, country or area *']=='China']

# %%
df_PC
# Out:
#     Index    Variant Region, subregion, country or area * Notes  Country code  \
# 78     79  Estimates                                China     4           156
#
#           1950        1951        1952        1953        1954     ...       \
# 78  554419.275  569611.075  582029.301  592567.861  601971.218     ...
#
#            2006         2007         2008         2009         2010  \
# 78  1329209.094  1336800.506  1344415.227  1352068.091  1359755.102
#
#            2011         2012         2013         2014         2015
# 78  1367480.264  1375198.619  1382793.212  1390110.388  1397028.553
#
# [1 rows x 71 columns]

# %%
df_PCN = df_PC.transpose().reset_index()

# %%
df_PCN
# Out:
#                                    index           78
# 0                                  Index           79
# 1                                Variant    Estimates
# 2   Region, subregion, country or area *        China
# 3                                  Notes            4
# 4                           Country code          156
# 5                                   1950       554419
# 6                                   1951       569611
# 7                                   1952       582029
# 8                                   1953       592568
# 9                                   1954       601971
# 10                                  1955       610834
# 11                                  1956       619598
# 12                                  1957       628551
# 13                                  1958       637854
# 14                                  1959       647556
# 15                                  1960       657686
# ...

# %%
df_PCN.rename(columns={'index': 'Year', 78: 'Population'}, inplace=True)

# %%
df_PCn = df_PCN.drop(df_PCN.index[[0,1,2,3,4]])

# %%
df_PCn.plot(x='Year')

# %%
df_mpop = pd.read_excel('TOTAL_POPULATION_BOTH_SEXES.xlsx', sheetname = 'MEDIUM VARIANT', skiprows=16)
df_mpop
# Out:
#      Index         Variant               Region, subregion, country or area *  \
# 0        1  Medium variant                                              WORLD
# 1        2  Medium variant                             More developed regions
# 2        3  Medium variant                             Less developed regions
# 3        4  Medium variant                          Least developed countries
# 4        5  Medium variant  Less developed regions, excluding least develo...
# 5        6  Medium variant            Less developed regions, excluding China
# 6        7  Medium variant                              High-income countries
# 7        8  Medium variant                            Middle-income countries
# 8        9  Medium variant                      Upper-middle-income countries
# 9       10  Medium variant                      Lower-middle-income countries
# 10      11  Medium variant                               Low-income countries
# ...

# %%
df_pc = df_mpop[df_mpop['Region, subregion, country or area *']=='China']

# %%
df_PC = df_pc.transpose().reset_index()

# %%
df_PC
# Out:
#                                    index              78
# 0                                  Index              79
# 1                                Variant  Medium variant
# 2   Region, subregion, country or area *           China
# 3                                  Notes               4
# 4                           Country code             156
# 5                                   2015     1.39703e+06
# 6                                   2016      1.4035e+06
# 7                                   2017     1.40952e+06
# 8                                   2018     1.41505e+06
# 9                                   2019     1.42006e+06
# 10                                  2020     1.42455e+06
# 11                                  2021     1.42848e+06
# 12                                  2022     1.43185e+06
# 13                                  2023     1.43468e+06
# 14                                  2024       1.437e+06
# ...

# %%
df_PC.rename(columns={'index': 'Year', 78: 'Population'}, inplace=True)

# %%
df_PCN = df_PC.drop(df_PC.index[[0,1,2,3,4]])

# %%
df_PCN.plot(x='Year')

# %%
df_per = pd.read_excel('Input_TFR.xls', sheetname = 'Median', skiprows=16)
df_per
# Out:
#      Index        Variant                  Country or area **  Notes  \
# 0        1  Median PI\n\n                         Afghanistan    NaN
# 1        2  Median PI\n\n                             Albania    NaN
# 2        3  Median PI\n\n                             Algeria    NaN
# 3        4  Median PI\n\n                              Angola    NaN
# 4        5  Median PI\n\n                 Antigua and Barbuda    NaN
# 5        6  Median PI\n\n                           Argentina    NaN
# 6        7  Median PI\n\n                             Armenia    NaN
# 7        8  Median PI\n\n                               Aruba    NaN
# 8        9  Median PI\n\n                           Australia    1.0
# 9       10  Median PI\n\n                             Austria    NaN
# 10      11  Median PI\n\n                          Azerbaijan    2.0
# 11      12  Median PI\n\n                             Bahamas    NaN
# 12      13  Median PI\n\n                             Bahrain    NaN
# ...

# %%
df_np = df_per[df_per['Country or area **']=='China'].transpose().reset_index()

# %%
df_np
# Out:
#                  index             36
# 0                Index             37
# 1              Variant  Median PI\n\n
# 2   Country or area **          China
# 3                Notes              4
# 4         Country code            156
# 5            2015-2020         1.6348
# 6            2020-2025         1.6636
# 7            2025-2030         1.6866
# 8            2030-2035         1.7055
# 9            2035-2040         1.7223
# 10           2040-2045         1.7362
# 11           2045-2050         1.7483
# 12           2050-2055         1.7578
# 13           2055-2060         1.7654
# 14           2060-2065         1.7735
# 15           2065-2070         1.7799
# 16           2070-2075         1.7863
# 17           2075-2080         1.7901
# 18           2080-2085         1.7932
# 19           2085-2090         1.7965
# 20           2090-2095         1.7995
# 21           2095-2100         1.8022

# %%
df_CHN = df_np.drop(df_np.index[[0,1,2,3,4]])

# %%
df_CHN
# Out:
#         index      36
# 5   2015-2020  1.6348
# 6   2020-2025  1.6636
# 7   2025-2030  1.6866
# 8   2030-2035  1.7055
# 9   2035-2040  1.7223
# 10  2040-2045  1.7362
# 11  2045-2050  1.7483
# 12  2050-2055  1.7578
# 13  2055-2060  1.7654
# 14  2060-2065  1.7735
# 15  2065-2070  1.7799
# 16  2070-2075  1.7863
# 17  2075-2080  1.7901
# 18  2080-2085  1.7932
# 19  2085-2090  1.7965
# 20  2090-2095  1.7995
# 21  2095-2100  1.8022

# %%
df_CHN.rename(columns={'index': 'Year', 36: 'Fertility Rate'}, inplace=True)
df_CHN
# Out:
#          Year Fertility Rate
# 5   2015-2020         1.6348
# 6   2020-2025         1.6636
# 7   2025-2030         1.6866
# 8   2030-2035         1.7055
# 9   2035-2040         1.7223
# 10  2040-2045         1.7362
# 11  2045-2050         1.7483
# 12  2050-2055         1.7578
# 13  2055-2060         1.7654
# 14  2060-2065         1.7735
# 15  2065-2070         1.7799
# 16  2070-2075         1.7863
# 17  2075-2080         1.7901
# 18  2080-2085         1.7932
# 19  2085-2090         1.7965
# 20  2090-2095         1.7995
# 21  2095-2100         1.8022

# %%
df_CHN.plot(x='Year', y='Fertility Rate')

# %%
df_np = df_per[df_per['Country or area **']=='China'].transpose().reset_index()

# %%
#df1 = df_per[df_per['Country Name']=='World'].transpose().reset_index()
