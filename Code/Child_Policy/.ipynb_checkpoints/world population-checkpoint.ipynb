# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_excel('1960.xlsx', skiprows=16)
df
# Out:
#     Region, subregion, country or area *  Population
# 0                                Burundi    2786.106
# 1                                Comoros     191.121
# 2                               Djibouti      83.636
# 3                                Eritrea    1397.491
# 4                               Ethiopia   22151.278
# 5                                  Kenya    8105.440
# 6                             Madagascar    5099.373
# 7                                 Malawi    3618.595
# 8                              Mauritius     660.023
# 9                                Mayotte      24.015
# 10                            Mozambique    7388.695
# 11                               Réunion     335.693
# 12                                Rwanda    2933.428
# 13                            Seychelles      41.540
# 14                               Somalia    2755.947
# 15                           South Sudan    2955.152
# 16                                Uganda    6788.214
# ...

# %%
df.sort_values(by='Population').tail(10).plot(kind='barh', x='Region, subregion, country or area *', y='Population', legend=False)
plt.tight_layout()
plt.savefig("1960.pdf")

# %%
df2 = pd.read_excel('2010.xlsx', skiprows=16)
df2
# Out:
#     Region, subregion, country or area *  Population
# 0                                Burundi    8766.930
# 1                                Comoros     689.692
# 2                               Djibouti     851.146
# 3                                Eritrea    4390.840
# 4                               Ethiopia   87702.670
# 5                                  Kenya   41350.152
# 6                             Madagascar   21151.640
# 7                                 Malawi   15167.095
# 8                              Mauritius    1247.955
# 9                                Mayotte     208.718
# 10                            Mozambique   24221.405
# 11                               Réunion     830.519
# 12                                Rwanda   10246.842
# 13                            Seychelles      91.405
# 14                               Somalia   12053.223
# 15                           South Sudan   10067.192
# 16                                Uganda   33915.133
# ...

# %%
df2.sort_values(by='Population').tail(10).plot(kind='barh', x='Region, subregion, country or area *', y='Population', legend=False)
plt.tight_layout()
plt.savefig("2010.pdf")

# %%
df3 = pd.read_excel('2050.xlsx', skiprows=16)
df3
# Out:
#     Region, subregion, country or area *  Population
# 0                                Burundi   25762.044
# 1                                Comoros    1462.735
# 2                               Djibouti    1307.615
# 3                                Eritrea    9606.664
# 4                               Ethiopia  190869.632
# 5                                  Kenya   95467.137
# 6                             Madagascar   53802.574
# 7                                 Malawi   41705.002
# 8                              Mauritius    1221.030
# 9                                Mayotte     495.498
# 10                            Mozambique   67774.943
# 11                               Réunion    1013.561
# 12                                Rwanda   21886.077
# 13                            Seychelles      96.643
# 14                               Somalia   35851.792
# 15                           South Sudan   25366.221
# 16                                Uganda  105698.201
# ...

# %%
df3.sort_values(by='Population').tail(10).plot(kind='barh', x='Region, subregion, country or area *', y='Population', legend=False)
plt.tight_layout()
plt.savefig("2050.pdf")
